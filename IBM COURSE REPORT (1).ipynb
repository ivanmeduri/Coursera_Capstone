# %% [markdown]
# # Analysis of Real Estate and Schools Levels of the Toronto Etobicoke Borough and its Neighborhoods

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# This research focuses on the attractiveness from multiple standpoints of the Etobicoke borough of Toronto and its neighborhoods.
# The objective is to show multiple data points specific to the borough.
# We will particularly analyze a data set of the average housing pricing as well as the schools levels ratings in order to define the best schools and the best area in the borough.

# %% [markdown]
# # 2. Business Problem

# %% [markdown]
# Segmentation of multiple data points for different neighborhoods will effectively help Toronto inhabitants to take data-driven decisions on where they want to live. The population of the city should have in-depth information at their disposal based on data, that helps them to make these decisions. In the report, we will consider proximity to specific categories of venues and locations, as well as average housing prices and proximity to high level schools as two main elements that drive this data analysis project.

# %% [markdown]
# # 3. Data Description

# %% [markdown]
# ## 3.1 Neighborhood Data

# %% [markdown]
# The data for the Etobicoke neighborhood and all the Toronto neighborhoods has been extracted through web scraping and BeatifulSoup from this Wikipedia data set link: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# # 3.2 Venues Data

# %% [markdown]
# The venues data is taken by passing the required parameters through the Foursquare API and creating a new Dataframe that contains all the venues in each specific neighborhood.
#
# Foursquare API Data: We will use Foursquare locational data through API in order to get all the neighborhood venues and data, including:
# - Neighborhood
# - Neighborhood Latitude
# - Neighborhood Longitude
# - Venue
# - Name of the venue e.g. the name of a store or restaurant
# - Venue Latitude
# - Venue Longitude
# - Venue Category

# %% [markdown]
# Libraries:
# - Pandas: To create and manipulate data frames.
# - Folium: Python visualization library would be used to visualize the neighborhood cluster distribution of using an interactive leaflet map.
# - Scikit Learn: To import k-means clustering.
# - JSON: Library to handle JSON files.
# - XML: To separate data from presentation and XML stores data in plain text format.
# - Geocoder: To retrieve Location Data.
# - Beautiful Soup and Requests: To scrap and library to handle HTTP requests.
# - Matplotlib: To Python Plotting Module.

# %% [markdown]
# # 4. Methodology

# %% [markdown]
# ## 4.1 Folium

# %% [markdown]
# We have used the Folium library for data wrangling and to build a map of the city and the neighborhoods

# %% [markdown]
# ## 4.2 One hot encoding

# %% [markdown]
# One hot encoding is the process to convert categorical values for a better prediction values.During the K-means clustering phase, all the Venues Category have been one hot encoded.

# %% [markdown]
# - Data extraction using BeautifulSoup and cleaning up the resulting data set from Wikipedia
# - Working out the latitude and longitude of the Etobicoke borough in Toronto
# - Generate a map of the borough
# - Use Foursquare API to explore the venues and return the results in the selected borough
# - Use Foursqare API to check nearby venues
# - Check all the categories of the nearby venues, in order to determine the type of venues in the borough
# - Check the most common venues in the neighborhood
# - Work with K-Means Clusters
# - Generate map of K-clusters
# - Check the average housing price and generate barchart using matplotlib
# - Check the schools rating rankings and generate barchart using matplotlib

# %% [markdown]
# ## 4.3 Detect Most Common Venues

# %% [markdown]
# We have selected the most common venues and created a new dataframe with them and this is been used to train the K-means clustering approach.

# %% [markdown]
# ## 4.4 K-means Clustering

# %% [markdown]
# We have trained the venue dataset using K-means clustering to return the 10 clusters to analyze.

# %% [markdown]
# ![Jupyter-Notebook-Viewer.png](attachment:Jupyter-Notebook-Viewer.png)

# %% [markdown]
# ## 5. Results

# %% [markdown]
# The neighborhood has been divided into 10 clusters. The clustered neighborhoods are visualized with multiple colors based on their proximity to the most common venues found via the Foursquare API calls.

# %% [markdown]
# ## 6. Discussion

# %% [markdown]
# After analyzing the different clusters, we can see the separation of the most common venues based on the Foursquare data below.

# %% [markdown]
# ![Coursera_Capstone-IBM-FINAL-COURSE-ipynb-at-master-%C2%B7-ivanmeduri-Coursera_Capstone-%C2%B7-GitHub.png](attachment:Coursera_Capstone-IBM-FINAL-COURSE-ipynb-at-master-%C2%B7-ivanmeduri-Coursera_Capstone-%C2%B7-GitHub.png)

# %% [markdown]
# ## 7. Conclusion

# %% [markdown]
# Main conclusions observed based on the data in the notebook:
#     - We are able to provide a list of the most common locations in each neighborhood
#     - Using K-means cluster, we have separated the larger borough into 10 clusters that have most similar characteristics and features
#     - We were able to provide 2 barcharts with the data on average housing pricing and average school ranking indexes for each of the neighborhoods in all the 10 clusters
