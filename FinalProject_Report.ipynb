# %% [markdown]
# ## IBM Data Science Professional Certificate - Coursera

# %% [markdown]
# ## 1. Introduction/Business Problem

# %% [markdown]
# Barcelona is one of the biggest tourism destinations in the world with almost 10 million visitors a year and steadily growing.
#
# The client is a real estate company that needs data to choose a location for a new hotel or vacation rental apartment building in Barcelona, either by acquisition of a single unit or a full building.
#
# There are some criteria that have to be satisfied in order to achieve the highest revenue per occupied night for the new location:
#
# - the current density of hospitality establishments in each neighborhood
# - the density of the population
# - the tourist demand in each area
# - the demographic of tourists in each area
# - seasonality patterns
#
# In this project, we will implement the basic analysis and try to find the most optimal area to consider opening the new hospitality establishment according to some of those criteria. The main objective is finding the most profitable area.

# %% [markdown]
# ## 2. Data Description

# %%
Based on criteria listed above the following data will be utilized in this analysis:

- multiple data points on each hotel in Barcelona, including neighborhood, latitude, longitude: https://opendata-ajuntament.barcelona.cat/resources/bcn/Asia_Allotjaments/B002_Hotels.csv
-
